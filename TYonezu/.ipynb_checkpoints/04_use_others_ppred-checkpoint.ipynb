# %% [markdown]
# ### **Make Uncertainty Prediction from Point Prediction made by others**

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import os
import glob
import pickle
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['agg.path.chunksize'] = 100000

from myConfig import *
import gc
from myUtils import *

# %%
ppred_path = os.path.join("submission_point","M5 - Dark Witch Time by Store -  submission.csv")
sub = pd.read_csv(ppred_path)

sales = pd.read_csv(os.path.join("rawdata","sales_train_validation.csv"))
sub = pd.merge(sub,sales[["id", "item_id", "dept_id", "cat_id", "store_id", "state_id"]], on = "id")
sub["_all_"] = "Total"

del sales
gc.collect()

sub = point2unc(sub)
sub
# Out:
#                                        id           F1           F2  \
# 0       FOODS_1_001_CA_1_0.005_validation    -2.805999    -2.524034
# 1       FOODS_1_001_CA_2_0.005_validation    -3.757051    -3.624542
# 2       FOODS_1_001_CA_3_0.005_validation    -3.182488    -2.996900
# 3       FOODS_1_001_CA_4_0.005_validation    -1.524496    -1.335591
# 4       FOODS_1_001_TX_1_0.005_validation    -0.216624    -1.094321
# ...                                   ...          ...          ...
# 771115      WI_2_HOBBIES_0.995_evaluation   912.184493   893.339695
# 771116    WI_2_HOUSEHOLD_0.995_evaluation  3339.661378  3242.107822
# 771117        WI_3_FOODS_0.995_evaluation  7875.641938  7462.024340
# 771118      WI_3_HOBBIES_0.995_evaluation   846.234848   832.758634
# 771119    WI_3_HOUSEHOLD_0.995_evaluation  2457.347206  2276.588993
#
#                  F3           F4           F5            F6            F7  \
# 0         -2.397262    -2.465210    -3.265820     -3.330283     -3.522940
# 1         -3.527942    -3.401376    -3.525762     -4.394335     -5.687738
# 2         -2.904139    -2.903552    -3.535026     -4.525715     -5.249040
# 3         -1.179699    -1.261834    -1.217565     -1.263589     -1.140473
# 4         -1.152550    -1.140007    -1.181637     -1.321053     -1.805429
# ...             ...          ...          ...           ...           ...
# 771115   904.755737   932.928419  1138.971502   1160.899642   1076.670732
# 771116  3350.743137  3611.648164  4986.745412   5095.846917   4762.132455
# 771117  7100.485822  7295.406471  9179.841212  11346.034241  10671.132187
# 771118   831.085008   843.981370  1135.091764   1212.769445    982.597658
# 771119  2186.975456  2239.097864  3249.679515   3851.287562   3517.208258
#
#                   F8            F9  ...           F19           F20  \
# 0          -3.014366     -2.617508  ...     -3.102210     -3.316891
# 1          -3.843273     -4.154251  ...     -4.306662     -4.911112
# 2          -3.251174     -3.071401  ...     -3.571770     -5.025659
# 3          -1.298223     -1.217691  ...     -1.343564     -1.508167
# 4          -1.433890     -1.600316  ...     -1.508634     -1.596053
# ...              ...           ...  ...           ...           ...
# 771115   1089.892083   1102.750204  ...   1087.775789   1217.803689
# 771116   4289.235199   4490.146698  ...   4316.814858   4759.137074
# 771117  11455.749616  12011.148725  ...  10438.833511  14262.770724
# 771118    932.900950    989.177239  ...   1121.554503   1197.871449
# 771119   2950.701125   2954.405766  ...   3075.585581   3635.422123
#
#                  F21          F22          F23          F24          F25  \
# 0          -3.193678    -2.670032    -2.456137    -2.459133    -2.172334
# 1          -4.709627    -3.370070    -3.637392    -3.483457    -3.721110
# 2          -5.502820    -3.061383    -2.924283    -3.221952    -2.864101
# 3          -1.422676    -1.461008    -1.129262    -1.275525    -1.310034
# 4          -1.646417    -1.492410    -1.453017    -1.347388    -1.368988
# ...              ...          ...          ...          ...          ...
# 771115   1078.716249   989.641831   934.968537   948.105543   958.402889
# 771116   4299.406999  3612.806868  3392.483800  3439.301914  3548.592870
# 771117  14549.109540  9935.008285  8728.398777  8185.096547  8159.476872
# 771118   1075.025997   939.106923   870.932760   869.732230   888.003948
# 771119   3565.272290  2729.600132  2450.284043  2328.042691  2392.007220
#
#                 F26           F27           F28
# 0         -2.900161     -3.270610     -2.615055
# 1         -3.670992     -4.304923     -4.504873
# 2         -3.571045     -4.813141     -4.890584
# 3         -1.306271     -1.367444     -1.272919
# 4         -1.307465     -1.552763     -1.636370
# ...             ...           ...           ...
# 771115  1105.480122   1188.827782   1034.761663
# 771116  4333.231682   4727.917444   4066.530750
# 771117  9475.764357  11231.381829  10929.918161
# 771118  1108.359976   1166.288069   1016.569789
# 771119  3107.222722   3559.662721   3408.419652
#
# [771120 rows x 29 columns]

# %%
model_name = "None_model_with_others_ppred_v1"
sub_path = os.path.join("submission_uncertainty","others_ppred_v1.csv")
sub.to_csv(sub_path,index=False)

# submit csv-file
import subprocess

command = ["kaggle","competitions","submit","-c","m5-forecasting-uncertainty","-f",sub_path,"-m",model_name]
subprocess.check_output(command)
# Out:
# b'Successfully submitted to M5 Forecasting - Uncertainty'
