# %% [markdown]
# ### **Make Uncertainty Prediction from Point Prediction made by others**

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import os
import glob
import pickle
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['agg.path.chunksize'] = 100000

from myConfig import *
import gc
from myUtils import *
from ppred2upred_v2 import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ppred_path = os.path.join("submission_point","M5 - Dark Witch Time by Store -  submission.csv")
sub = pd.read_csv(ppred_path)

sales = pd.read_csv(os.path.join("rawdata","sales_train_validation.csv"))
sub = pd.merge(sub,sales[["id", "item_id", "dept_id", "cat_id", "store_id", "state_id"]], on = "id")
sub["_all_"] = "Total"

del sales
gc.collect()

sub = point2unc(sub)
sub
# Out:
#                                        id           F1           F2  \
# 0       FOODS_1_001_CA_1_0.005_validation     0.091341     0.082162
# 1       FOODS_1_001_CA_2_0.005_validation     0.122300     0.117986
# 2       FOODS_1_001_CA_3_0.005_validation     0.103596     0.097555
# 3       FOODS_1_001_CA_4_0.005_validation     0.049625     0.043476
# 4       FOODS_1_001_TX_1_0.005_validation     0.007052     0.035622
# ...                                   ...          ...          ...
# 771115      WI_2_HOBBIES_0.995_evaluation   371.963303   364.278922
# 771116    WI_2_HOUSEHOLD_0.995_evaluation  1361.820427  1322.040817
# 771117        WI_3_FOODS_0.995_evaluation  3211.466329  3042.804651
# 771118      WI_3_HOBBIES_0.995_evaluation   345.070883   339.575661
# 771119    WI_3_HOUSEHOLD_0.995_evaluation  1002.037405   928.329266
#
#                  F3           F4           F5           F6           F7  \
# 0          0.078036     0.080248     0.106309     0.108407     0.114679
# 1          0.114842     0.110722     0.114771     0.143044     0.185147
# 2          0.094536     0.094516     0.115072     0.147321     0.170867
# 3          0.038402     0.041075     0.039634     0.041132     0.037125
# 4          0.037518     0.037110     0.038465     0.043003     0.058770
# ...             ...          ...          ...          ...          ...
# 771115   368.934064   380.422095   464.440697   473.382378   439.036186
# 771116  1366.339258  1472.729025  2033.455191  2077.943731  1941.864315
# 771117  2895.379363  2974.862547  3743.282286  4626.595168  4351.389002
# 771118   338.893203   344.151978   462.858648   494.533432   400.675820
# 771119   891.787374   913.041433  1325.128342  1570.447264  1434.219075
#
#                  F8           F9  ...          F19          F20          F21  \
# 0          0.098124     0.085205  ...     0.100983     0.107971     0.103961
# 1          0.125106     0.135229  ...     0.140190     0.159867     0.153308
# 2          0.105832     0.099980  ...     0.116268     0.163595     0.179128
# 3          0.042260     0.039638  ...     0.043736     0.049094     0.046311
# 4          0.046676     0.052093  ...     0.049109     0.051955     0.053594
# ...             ...          ...  ...          ...          ...          ...
# 771115   444.427484   449.670665  ...   443.564518   496.586256   439.870291
# 771116  1749.030051  1830.956136  ...  1760.276264  1940.642882  1753.177826
# 771117  4671.334027  4897.810236  ...  4256.664104  5815.958661  5932.719615
# 771118   380.410894   403.358789  ...   457.338532   488.458447   438.365510
# 771119  1203.213323  1204.723972  ...  1254.137709  1482.423380  1453.818241
#
#                 F22          F23          F24          F25          F26  \
# 0          0.086915     0.079952     0.080050     0.070714     0.094406
# 1          0.109703     0.118404     0.113394     0.121130     0.119498
# 2          0.099654     0.095191     0.104881     0.093232     0.116245
# 3          0.047559     0.036760     0.041521     0.042644     0.042522
# 4          0.048581     0.047299     0.043860     0.044563     0.042561
# ...             ...          ...          ...          ...          ...
# 771115   403.548237   381.253998   386.610901   390.809871   450.783849
# 771116  1473.201512  1383.359932  1402.451048  1447.016841  1766.970585
# 771117  4051.218280  3559.196698  3337.653256  3327.206270  3863.951461
# 771118   382.941516   355.142001   354.652458   362.103153   451.958173
# 771119  1113.054528   999.157245   949.310644   975.393588  1267.038449
#
#                 F27          F28
# 0          0.106465     0.085125
# 1          0.140134     0.146643
# 2          0.156677     0.159198
# 3          0.044513     0.041436
# 4          0.050546     0.053267
# ...             ...          ...
# 771115   484.770692   421.946841
# 771116  1927.912391  1658.217410
# 771117  4579.843123  4456.914678
# 771118   475.579628   414.528704
# 771119  1451.530816  1389.858126
#
# [771120 rows x 29 columns]

# %%
model_name = "None_model_with_others_ppred_v2"
sub_path = os.path.join("submission_uncertainty",model_name+".csv")
sub.to_csv(sub_path,index=False)

# submit csv-file
import subprocess

command = ["kaggle","competitions","submit","-c","m5-forecasting-uncertainty","-f",sub_path,"-m",model_name]
subprocess.check_output(command)
# Out:
# b'Successfully submitted to M5 Forecasting - Uncertainty'
