# %% [markdown]
# ### **特徴量 ver1**
# 店舗の情報, 商品の情報, イベント情報, 日時情報, 価格情報

# %%
import pandas as pd
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import matplotlib as mpl
from myUtils import reduce_mem_usage,encode_categorical
mpl.rcParams['agg.path.chunksize'] = 100000

# %% [markdown]
# #### **submitから特徴量を作っていく**

# %%
submission = pd.read_csv(os.path.join("rawdata","sample_submission.csv"))

# %%
valid_data = submission.iloc[0:int(len(submission)/2),:]
valid_data = valid_data.iloc[-30490:,:]

eval_data = submission.iloc[int(len(submission)/2):,:]
eval_data = eval_data.iloc[-30490:,:]

forecast_submission = pd.concat([valid_data,eval_data])
forecast_submission['id'] = forecast_submission['id'].str.replace('_.\...._','_')

display(forecast_submission)
# Out:
#                                    id  F1  F2  F3  F4  F5  F6  F7  F8  F9  \
# 355070  HOBBIES_1_001_CA_1_validation   0   0   0   0   0   0   0   0   0
# 355071  HOBBIES_1_002_CA_1_validation   0   0   0   0   0   0   0   0   0
# 355072  HOBBIES_1_003_CA_1_validation   0   0   0   0   0   0   0   0   0
# 355073  HOBBIES_1_004_CA_1_validation   0   0   0   0   0   0   0   0   0
# 355074  HOBBIES_1_005_CA_1_validation   0   0   0   0   0   0   0   0   0
# ...                               ...  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 771115    FOODS_3_823_WI_3_evaluation   0   0   0   0   0   0   0   0   0
# 771116    FOODS_3_824_WI_3_evaluation   0   0   0   0   0   0   0   0   0
# 771117    FOODS_3_825_WI_3_evaluation   0   0   0   0   0   0   0   0   0
# 771118    FOODS_3_826_WI_3_evaluation   0   0   0   0   0   0   0   0   0
# 771119    FOODS_3_827_WI_3_evaluation   0   0   0   0   0   0   0   0   0
#
#         ...  F19  F20  F21  F22  F23  F24  F25  F26  F27  F28
# ...

# %%
forecast_submission["data_type"] = forecast_submission["id"].str.split("_",expand=True)[5]
display(forecast_submission)
# Out:
#                                    id  F1  F2  F3  F4  F5  F6  F7  F8  F9  \
# 355070  HOBBIES_1_001_CA_1_validation   0   0   0   0   0   0   0   0   0
# 355071  HOBBIES_1_002_CA_1_validation   0   0   0   0   0   0   0   0   0
# 355072  HOBBIES_1_003_CA_1_validation   0   0   0   0   0   0   0   0   0
# 355073  HOBBIES_1_004_CA_1_validation   0   0   0   0   0   0   0   0   0
# 355074  HOBBIES_1_005_CA_1_validation   0   0   0   0   0   0   0   0   0
# ...                               ...  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 771115    FOODS_3_823_WI_3_evaluation   0   0   0   0   0   0   0   0   0
# 771116    FOODS_3_824_WI_3_evaluation   0   0   0   0   0   0   0   0   0
# 771117    FOODS_3_825_WI_3_evaluation   0   0   0   0   0   0   0   0   0
# 771118    FOODS_3_826_WI_3_evaluation   0   0   0   0   0   0   0   0   0
# 771119    FOODS_3_827_WI_3_evaluation   0   0   0   0   0   0   0   0   0
#
#         ...  F20  F21  F22  F23  F24  F25  F26  F27  F28   data_type
# ...

# %%
DAYS_PRED = 28

valid_data = forecast_submission[forecast_submission["data_type"] == "validation"]
valid_data.columns = ["id"] + [f"d_{d}" for d in range(1914, 1914 + DAYS_PRED)]

eval_data =  forecast_submission[forecast_submission["data_type"] == "evaluation"]
eval_data.columns = ["id"] + [f"d_{d}" for d in range(1942, 1942 + DAYS_PRED)]
