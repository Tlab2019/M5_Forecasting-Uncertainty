# %% [markdown]
# ## **データ整理**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
from tqdm import tqdm

from myUtils import reduce_mem_usage

import gc

# %% [markdown]
# ### **sales_train_val - Preprocess**
# 1. validation用の日 d_1914,...,d_1942を追加
# 2. evaluation用の日 d_1943,...,d_1971を追加
# 3. d_1,...d_1971がカラム方向に並んでいるので, index方向に並べ替える

# %%
sales_train_val = pd.read_csv(os.path.join("rawdata","sales_train_validation.csv")) # データの読み出し
sales_train_val = sales_train_val.set_index(["id","item_id","dept_id","cat_id","store_id","state_id"],drop=True)
display(sales_train_val)
# Out:
#                                                                                  d_1  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA          0
# ...                                                                              ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI          0
#
#                                                                                  d_2  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA          0
# ...                                                                              ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI          6
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI          0
#
#                                                                                  d_3  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA          0
# ...                                                                              ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI          2
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI          0
#
#                                                                                  d_4  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA          0
# ...                                                                              ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI          2
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI          2
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI          0
#
#                                                                                  d_5  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA          0
# ...                                                                              ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI          2
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI          0
#
#                                                                                  d_6  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA          0
# ...                                                                              ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI          3
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI          5
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI          4
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI          0
#
#                                                                                  d_7  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA          0
# ...                                                                              ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI          1
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI          1
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI          0
#
#                                                                                  d_8  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA          0
# ...                                                                              ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI          4
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI          1
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI          8
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI          0
#
#                                                                                  d_9  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA          0
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA          0
# ...                                                                              ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI          1
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI          1
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI          5
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI          0
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI          0
#
#                                                                                  d_10  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA           0
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA           0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA           0
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA           0
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA           0
# ...                                                                               ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI           0
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI           3
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI           2
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI           0
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI           0
#
#                                                                                  ...  \
# id                            item_id       dept_id   cat_id  store_id state_id  ...
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA        ...
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA        ...
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA        ...
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA        ...
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA        ...
# ...                                                                              ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI        ...
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI        ...
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI        ...
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI        ...
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI        ...
#
#                                                                                  d_1904  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA             1
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA             0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA             2
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA             1
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA             2
# ...                                                                                 ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI             2
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI             2
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI             0
#
#                                                                                  d_1905  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA             3
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA             0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA             1
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA             0
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA             1
# ...                                                                                 ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI             1
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI             0
#
#                                                                                  d_1906  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA             0
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA             0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA             2
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA             5
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA             1
# ...                                                                                 ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI             1
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI             0
#
#                                                                                  d_1907  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA             1
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA             0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA             1
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA             4
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA             0
# ...                                                                                 ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI             2
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI             0
#
#                                                                                  d_1908  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA             1
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA             0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA             1
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA             1
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA             1
# ...                                                                                 ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI             0
#
#                                                                                  d_1909  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA             1
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA             1
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA             1
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA             0
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA             1
# ...                                                                                 ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI             1
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI             1
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI             0
#
#                                                                                  d_1910  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA             3
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA             0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA             0
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA             1
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA             2
# ...                                                                                 ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI             1
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI             0
#
#                                                                                  d_1911  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA             0
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA             0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA             1
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA             3
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA             2
# ...                                                                                 ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI             3
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI             0
#
#                                                                                  d_1912  \
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA             1
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA             0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA             1
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA             7
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA             2
# ...                                                                                 ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI             1
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI             1
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI             1
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI             0
#
#                                                                                  d_1913
# id                            item_id       dept_id   cat_id  store_id state_id
# HOBBIES_1_001_CA_1_validation HOBBIES_1_001 HOBBIES_1 HOBBIES CA_1     CA             1
# HOBBIES_1_002_CA_1_validation HOBBIES_1_002 HOBBIES_1 HOBBIES CA_1     CA             0
# HOBBIES_1_003_CA_1_validation HOBBIES_1_003 HOBBIES_1 HOBBIES CA_1     CA             1
# HOBBIES_1_004_CA_1_validation HOBBIES_1_004 HOBBIES_1 HOBBIES CA_1     CA             2
# HOBBIES_1_005_CA_1_validation HOBBIES_1_005 HOBBIES_1 HOBBIES CA_1     CA             4
# ...                                                                                 ...
# FOODS_3_823_WI_3_validation   FOODS_3_823   FOODS_3   FOODS   WI_3     WI             1
# FOODS_3_824_WI_3_validation   FOODS_3_824   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_825_WI_3_validation   FOODS_3_825   FOODS_3   FOODS   WI_3     WI             0
# FOODS_3_826_WI_3_validation   FOODS_3_826   FOODS_3   FOODS   WI_3     WI             3
# FOODS_3_827_WI_3_validation   FOODS_3_827   FOODS_3   FOODS   WI_3     WI             0
#
# [30490 rows x 1913 columns]

# %%
# validation,evaluation用 の日をくっつける
valid_data = pd.DataFrame(index=sales_train_val.index,
                          columns=[f"d_{d}" for d in range(1914, 1942)],
                          data=np.nan)
eval_data = pd.DataFrame(index=sales_train_val.index,
                          columns=[f"d_{d}" for d in range(1942, 1970)],
                          data=np.nan)

sales_train_val = sales_train_val.join(valid_data)
sales_train_val = sales_train_val.join(eval_data)
sales_train_val = sales_train_val.reset_index()

# メモリ開放
del valid_data, eval_data
gc.collect()
# Out:
# 1698

# %%
# d_1,..を縦方向に変換
sales_train_val = pd.melt(sales_train_val,
                          id_vars = ['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'],
                          var_name = 'd', value_name = 'item_cnt')
sales_train_val = reduce_mem_usage(sales_train_val)

display(sales_train_val)
# Out:
# Mem. usage decreased to 3320.71 Mb (9.4% reduction)
#                                      id        item_id    dept_id   cat_id  \
# 0         HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 1         HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES
# 2         HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES
# 3         HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES
# 4         HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES
# ...                                 ...            ...        ...      ...
# 60034805    FOODS_3_823_WI_3_validation    FOODS_3_823    FOODS_3    FOODS
# 60034806    FOODS_3_824_WI_3_validation    FOODS_3_824    FOODS_3    FOODS
# 60034807    FOODS_3_825_WI_3_validation    FOODS_3_825    FOODS_3    FOODS
# 60034808    FOODS_3_826_WI_3_validation    FOODS_3_826    FOODS_3    FOODS
# 60034809    FOODS_3_827_WI_3_validation    FOODS_3_827    FOODS_3    FOODS
#
#          store_id state_id       d  item_cnt
# 0            CA_1       CA     d_1       0.0
# 1            CA_1       CA     d_1       0.0
# 2            CA_1       CA     d_1       0.0
# 3            CA_1       CA     d_1       0.0
# 4            CA_1       CA     d_1       0.0
# ...           ...      ...     ...       ...
# 60034805     WI_3       WI  d_1969       NaN
# 60034806     WI_3       WI  d_1969       NaN
# 60034807     WI_3       WI  d_1969       NaN
# 60034808     WI_3       WI  d_1969       NaN
# 60034809     WI_3       WI  d_1969       NaN
#
# [60034810 rows x 8 columns]

# %%
day = (sales_train_val["d"].str.split("_",expand=True))[1].astype("int64")
day

sales_train_val["data_part"] = "train"
sales_train_val.loc[(1914 <= day)&(day <= 1942),"data_part"] = "validation"
sales_train_val.loc[(1942 <= day)&(day <= 1970),"data_part"] = "evaluation"

display(sales_train_val)
# Out:
#                                      id        item_id    dept_id   cat_id  \
# 0         HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 1         HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES
# 2         HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES
# 3         HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES
# 4         HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES
# ...                                 ...            ...        ...      ...
# 60034805    FOODS_3_823_WI_3_validation    FOODS_3_823    FOODS_3    FOODS
# 60034806    FOODS_3_824_WI_3_validation    FOODS_3_824    FOODS_3    FOODS
# 60034807    FOODS_3_825_WI_3_validation    FOODS_3_825    FOODS_3    FOODS
# 60034808    FOODS_3_826_WI_3_validation    FOODS_3_826    FOODS_3    FOODS
# 60034809    FOODS_3_827_WI_3_validation    FOODS_3_827    FOODS_3    FOODS
#
#          store_id state_id       d  item_cnt   data_part
# 0            CA_1       CA     d_1       0.0       train
# 1            CA_1       CA     d_1       0.0       train
# 2            CA_1       CA     d_1       0.0       train
# 3            CA_1       CA     d_1       0.0       train
# 4            CA_1       CA     d_1       0.0       train
# ...           ...      ...     ...       ...         ...
# 60034805     WI_3       WI  d_1969       NaN  evaluation
# 60034806     WI_3       WI  d_1969       NaN  evaluation
# 60034807     WI_3       WI  d_1969       NaN  evaluation
# 60034808     WI_3       WI  d_1969       NaN  evaluation
# 60034809     WI_3       WI  d_1969       NaN  evaluation
#
# [60034810 rows x 9 columns]

# %%
# データ書き出し
path = os.path.join("data","sales_train_val.pickle")
sales_train_val.to_pickle(path)
